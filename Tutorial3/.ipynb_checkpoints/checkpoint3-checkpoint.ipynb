# %% [markdown]
# <h1> The Challenge:</h1>
#
# Based off this dataset with school financial, enrollment, and achievement data, we are interested in what information is a useful indicator of student performance at the state level.
#
# This question is a bit too big for a checkpoint, however. Instead, we want you to look at smaller questions related to our overall goal. Here's the overview:
#
# 1. Choose a specific test to focus on
# >Math/Reading for 4/8 grade
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create 2 well-labeled visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Pick if you want to do a regression or classification task. For both cases, defined _exactly_ what you want to predict, and pick any model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a> and <a href="https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html">classifiers</a>).
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# ** Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# feel free to import other libraries! 
sns.set()
# Out:
# D:\Programs\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('states_edu.csv')
METRIC_COLUMN = 'AVG_MATH_4_SCORE'

# %% [markdown]
# Chosen test: AVG_MATH_4_SCORE

# %% [markdown]
# <h2> Cleanup (optional)</h2>
#
# _Use this space to rename columns, deal with missing data, etc._

# %%
# Using the same column naming scheme from the tutorial because the names are intuitive
df.rename({
    'GRADES_PK_G':'ENROLL_PREK',
    'GRADES_KG_G':'ENROLL_KINDER',
    'GRADES_4_G':'ENROLL_4',
    'GRADES_8_G':'ENROLL_8',
    'GRADES_12_G':'ENROLL_12',
    'GRADES_1_8_G':'ENROLL_PRIMARY',
    'GRADES_9_12_G':'ENROLL_HS',
    'GRADES_ALL_G':'ENROLL_ALL',
    'ENROLL':'ENROLL_ALL_EST'
    },
    axis=1,inplace=True)

# %%
# Lets see the available columns
df.columns
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL_ALL_EST', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'ENROLL_PREK', 'ENROLL_KINDER',
#        'ENROLL_4', 'ENROLL_8', 'ENROLL_12', 'ENROLL_PRIMARY', 'ENROLL_HS',
#        'ENROLL_ALL', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')

# %%
state_df = df[['STATE', METRIC_COLUMN]].groupby('STATE')

# Let us see how many test scores there are in each category
state_df.agg(['count'])
# Out:
#                      AVG_MATH_4_SCORE
#                                 count
# STATE
# ALABAMA                            11
# ALASKA                              9
# ARIZONA                            11
# ARKANSAS                           11
# CALIFORNIA                         11
# COLORADO                           10
# CONNECTICUT                        11
# DELAWARE                           10
# DISTRICT_OF_COLUMBIA               11
# DODEA                              10
# FLORIDA                            10
# GEORGIA                            11
# HAWAII                             11
# IDAHO                              11
# ILLINOIS                           10
# INDIANA                            11
# IOWA                               11
# KANSAS                             10
# KENTUCKY                           11
# LOUISIANA                          11
# MAINE                              11
# MARYLAND                           11
# MASSACHUSETTS                      11
# MICHIGAN                           11
# MINNESOTA                          11
# MISSISSIPPI                        11
# MISSOURI                           11
# MONTANA                            10
# NATIONAL                           13
# NEBRASKA                           11
# NEVADA                             10
# NEW_HAMPSHIRE                      10
# NEW_JERSEY                         10
# NEW_MEXICO                         11
# NEW_YORK                           11
# NORTH_CAROLINA                     11
# NORTH_DAKOTA                       11
# OHIO                               11
# OKLAHOMA                           11
# OREGON                             10
# PENNSYLVANIA                       10
# RHODE_ISLAND                       11
# SOUTH_CAROLINA                     11
# SOUTH_DAKOTA                        9
# TENNESSEE                          11
# TEXAS                              11
# UTAH                               11
# VERMONT                            10
# VIRGINIA                           11
# WASHINGTON                          9
# WEST_VIRGINIA                      11
# WISCONSIN                          10
# WYOMING                            11

# %%
# Lets see the head of the dataframe
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL_ALL_EST  TOTAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992             NaN      2678885.0
# 1      1992_ALASKA      ALASKA  1992             NaN      1049591.0
# 2     1992_ARIZONA     ARIZONA  1992             NaN      3258079.0
# 3    1992_ARKANSAS    ARKANSAS  1992             NaN      1711959.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992             NaN     26260025.0
#
#    FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0         304177.0      1659028.0       715680.0          2653798.0
# 1         106780.0       720711.0       222100.0           972488.0
# 2         297888.0      1369815.0      1590376.0          3401580.0
# 3         178571.0       958785.0       574603.0          1743022.0
# 4        2072470.0     16546514.0      7641041.0         27138832.0
#
#    INSTRUCTION_EXPENDITURE  ...  ENROLL_4  ENROLL_8  ENROLL_12  \
# 0                1481703.0  ...   57948.0   58025.0    41167.0
# 1                 498362.0  ...    9748.0    8789.0     6714.0
# 2                1435908.0  ...   55433.0   49081.0    37410.0
# 3                 964323.0  ...   34632.0   36011.0    27651.0
# 4               14358922.0  ...  418418.0  363296.0   270675.0
#
#    ENROLL_PRIMARY  ENROLL_HS  ENROLL_ALL  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  \
# 0             NaN        NaN    731634.0             208.0             252.0
# 1             NaN        NaN    122487.0               NaN               NaN
# 2             NaN        NaN    673477.0             215.0             265.0
# 3             NaN        NaN    441490.0             210.0             256.0
# 4             NaN        NaN   5254844.0             208.0             261.0
#
#    AVG_READING_4_SCORE  AVG_READING_8_SCORE
# 0                207.0                  NaN
# 1                  NaN                  NaN
# 2                209.0                  NaN
# 3                211.0                  NaN
# 4                202.0                  NaN
#
# [5 rows x 25 columns]

# %%
# performs missing data imputation by replacing the ENROLL missing data entries with sums of other enrollemnts
df.ENROLL_ALL = df.ENROLL_ALL.fillna(df.ENROLL_PREK + df.ENROLL_PRIMARY + df.ENROLL_HS)

# in case, there are still NaN, we fill the ENROLL_ALL_EST with the ENROLL_ALL data we just created
df.ENROLL_ALL_EST = df.ENROLL_ALL_EST.fillna(df.ENROLL_ALL)

# gets the number of NaNs per column
df.isna().sum()
# Out:
# PRIMARY_KEY                        0
# STATE                              0
# YEAR                               0
# ENROLL_ALL_EST                    83
# TOTAL_REVENUE                    440
# FEDERAL_REVENUE                  440
# STATE_REVENUE                    440
# LOCAL_REVENUE                    440
# TOTAL_EXPENDITURE                440
# INSTRUCTION_EXPENDITURE          440
# SUPPORT_SERVICES_EXPENDITURE     440
# OTHER_EXPENDITURE                491
# CAPITAL_OUTLAY_EXPENDITURE       440
# ENROLL_PREK                      173
# ENROLL_KINDER                     83
# ENROLL_4                          83
# ENROLL_8                          83
# ENROLL_12                         83
# ENROLL_PRIMARY                   695
# ENROLL_HS                        644
# ENROLL_ALL                        83
# AVG_MATH_4_SCORE                1150
# AVG_MATH_8_SCORE                1113
# AVG_READING_4_SCORE             1065
# AVG_READING_8_SCORE             1153
# dtype: int64

# %%
# get the funding related columns that we might use for feature selection
FUNDING_COLUMNS = ['TOTAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
                   'FEDERAL_REVENUE', 'SUPPORT_SERVICES_EXPENDITURE',
                   'CAPITAL_OUTLAY_EXPENDITURE', 'INSTRUCTION_EXPENDITURE']
# see if the #N NaNs  that show up in each are in the rows (if it is the same number, then they do)
df[FUNDING_COLUMNS].isna().any(axis=1).sum()
# Out:
# 440

# %%
# Drop those NaN as well as the NaNs for AVG_MATH_4_SCORE
df = df[df['TOTAL_REVENUE'].notna() & df['AVG_MATH_4_SCORE'].notna()]

# %%
# Verify that there are zero NaNs in those columns
df[['TOTAL_REVENUE', 'AVG_MATH_4_SCORE']].isna().sum()
# Out:
# TOTAL_REVENUE       0
# AVG_MATH_4_SCORE    0
# dtype: int64

# %%
# Lets just see the dataframe again
df
# Out:
#              PRIMARY_KEY          STATE  YEAR  ENROLL_ALL_EST  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992        731634.0      2678885.0
# 2           1992_ARIZONA        ARIZONA  1992        673477.0      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992        441490.0      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992       5254844.0     26260025.0
# 5          1992_COLORADO       COLORADO  1992        612635.0      3185173.0
# ...                  ...            ...   ...             ...            ...
# 1219       2015_VIRGINIA       VIRGINIA  2015       1279867.0     15857524.0
# 1220     2015_WASHINGTON     WASHINGTON  2015       1072359.0     13709442.0
# 1221  2015_WEST_VIRGINIA  WEST_VIRGINIA  2015        279565.0      3478401.0
# 1222      2015_WISCONSIN      WISCONSIN  2015        861813.0     11637376.0
# 1223        2015_WYOMING        WYOMING  2015         93867.0      1962874.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0            304177.0      1659028.0       715680.0          2653798.0
# 2            297888.0      1369815.0      1590376.0          3401580.0
# 3            178571.0       958785.0       574603.0          1743022.0
# 4           2072470.0     16546514.0      7641041.0         27138832.0
# 5            163253.0      1307986.0      1713934.0          3264826.0
# ...               ...            ...            ...                ...
# 1219        1012205.0      6240349.0      8604970.0         16113212.0
# 1220        1036422.0      8293812.0      4379208.0         13630138.0
# 1221         362959.0      1979466.0      1135976.0          3466981.0
# 1222         814385.0      5869265.0      4953726.0         11553677.0
# 1223         120290.0      1116917.0       725667.0          1942406.0
#
#       INSTRUCTION_EXPENDITURE  ...  ENROLL_4  ENROLL_8  ENROLL_12  \
# 0                   1481703.0  ...   57948.0   58025.0    41167.0
# 2                   1435908.0  ...   55433.0   49081.0    37410.0
# 3                    964323.0  ...   34632.0   36011.0    27651.0
# 4                  14358922.0  ...  418418.0  363296.0   270675.0
# 5                   1642466.0  ...   50648.0   45025.0    34533.0
# ...                       ...  ...       ...       ...        ...
# 1219                8755896.0  ...   96851.0   95221.0    90391.0
# 1220                6508964.0  ...   82404.0   79483.0    89258.0
# 1221                1819903.0  ...   19814.0   20426.0    18432.0
# 1222                5723474.0  ...   60999.0   61084.0    66253.0
# 1223                 895910.0  ...    7551.0    6902.0     6299.0
#
#       ENROLL_PRIMARY  ENROLL_HS  ENROLL_ALL  AVG_MATH_4_SCORE  \
# 0                NaN        NaN    731634.0             208.0
# 2                NaN        NaN    673477.0             215.0
# 3                NaN        NaN    441490.0             210.0
# 4                NaN        NaN   5254844.0             208.0
# 5                NaN        NaN    612635.0             221.0
# ...              ...        ...         ...               ...
# 1219        772414.0   386781.0   1283590.0             247.0
# 1220        656797.0   336808.0   1087030.0             245.0
# 1221        162070.0    80142.0    277452.0             235.0
# 1222        489919.0   263896.0    867800.0             243.0
# 1223         59453.0    26914.0     94717.0             247.0
#
#       AVG_MATH_8_SCORE  AVG_READING_4_SCORE  AVG_READING_8_SCORE
# 0                252.0                207.0                  NaN
# 2                265.0                209.0                  NaN
# 3                256.0                211.0                  NaN
# 4                261.0                202.0                  NaN
# 5                272.0                217.0                  NaN
# ...                ...                  ...                  ...
# 1219             288.0                229.0                267.0
# 1220             287.0                226.0                267.0
# 1221             271.0                216.0                260.0
# 1222             289.0                223.0                270.0
# 1223             287.0                228.0                269.0
#
# [440 rows x 25 columns]

# %% [markdown]
# <h2> Feature Selection </h2>
#
# _Use this space to modify or create features_

# %%
# Pair plots for the first three columns against the Average 4 Grade Math Scores
sns.pairplot(df, x_vars=FUNDING_COLUMNS[0:3], y_vars=METRIC_COLUMN,  kind='reg', height=4)

# %%
# Pair plots for the last three columns against the Average 4 Grade Math Scores
sns.pairplot(df, x_vars=FUNDING_COLUMNS[3:-1], y_vars=METRIC_COLUMN,  kind='reg', height=4)

# %% [markdown]
# Looking at the various scatter Since we are no entirely sure that the data is normal, it is based to assess the data using a nonparametric metric, such as Spearman's rank correlation

# %%
df[[*FUNDING_COLUMNS, METRIC_COLUMN]].corr(method='spearman')
# Out:
#                               TOTAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  \
# TOTAL_REVENUE                      1.000000       0.977192       0.953835
# STATE_REVENUE                      0.977192       1.000000       0.879387
# LOCAL_REVENUE                      0.953835       0.879387       1.000000
# FEDERAL_REVENUE                    0.933674       0.926372       0.858685
# SUPPORT_SERVICES_EXPENDITURE       0.995801       0.972536       0.950485
# CAPITAL_OUTLAY_EXPENDITURE         0.925391       0.916168       0.881429
# INSTRUCTION_EXPENDITURE            0.997652       0.972685       0.955624
# AVG_MATH_4_SCORE                   0.229522       0.220150       0.228187
#
#                               FEDERAL_REVENUE  SUPPORT_SERVICES_EXPENDITURE  \
# TOTAL_REVENUE                        0.933674                      0.995801
# STATE_REVENUE                        0.926372                      0.972536
# LOCAL_REVENUE                        0.858685                      0.950485
# FEDERAL_REVENUE                      1.000000                      0.940529
# SUPPORT_SERVICES_EXPENDITURE         0.940529                      1.000000
# CAPITAL_OUTLAY_EXPENDITURE           0.882154                      0.917099
# INSTRUCTION_EXPENDITURE              0.928463                      0.992878
# AVG_MATH_4_SCORE                     0.166295                      0.221183
#
#                               CAPITAL_OUTLAY_EXPENDITURE  \
# TOTAL_REVENUE                                   0.925391
# STATE_REVENUE                                   0.916168
# LOCAL_REVENUE                                   0.881429
# FEDERAL_REVENUE                                 0.882154
# SUPPORT_SERVICES_EXPENDITURE                    0.917099
# CAPITAL_OUTLAY_EXPENDITURE                      1.000000
# INSTRUCTION_EXPENDITURE                         0.916308
# AVG_MATH_4_SCORE                                0.166923
#
#                               INSTRUCTION_EXPENDITURE  AVG_MATH_4_SCORE
# TOTAL_REVENUE                                0.997652          0.229522
# STATE_REVENUE                                0.972685          0.220150
# LOCAL_REVENUE                                0.955624          0.228187
# FEDERAL_REVENUE                              0.928463          0.166295
# SUPPORT_SERVICES_EXPENDITURE                 0.992878          0.221183
# CAPITAL_OUTLAY_EXPENDITURE                   0.916308          0.166923
# INSTRUCTION_EXPENDITURE                      1.000000          0.226769
# AVG_MATH_4_SCORE                             0.226769          1.000000

# %% [markdown]
# However, we can see that though some of the features are correlated well with each other (e.g. LOCAL_REVENUE and FEDERAL_REVENUE), none of them are well correlated with AVG_MATH_4_SCORE. However, revenue and expenditure tell an incomplete picture and it might make sense to reevaluate them in terms of enrollment

# %%
# We will use this list to refer to columns that are in terms of per enrolled.
PER_COLUMNS = []

# Iterature over the previous columns
for COLUMN in FUNDING_COLUMNS:
    new_column = '{}_PER_ENROLLED'.format(COLUMN)
    
    # Calculates the column per enrolled
    df[new_column] = df[COLUMN] / df['ENROLL_ALL_EST']
    
    PER_COLUMNS.append(new_column)

# %%
# Lets calculate the spearman correlation matrix again
df[[*PER_COLUMNS, METRIC_COLUMN]].corr(method='spearman')
# Out:
#                                            TOTAL_REVENUE_PER_ENROLLED  \
# TOTAL_REVENUE_PER_ENROLLED                                   1.000000
# STATE_REVENUE_PER_ENROLLED                                   0.705124
# LOCAL_REVENUE_PER_ENROLLED                                   0.728422
# FEDERAL_REVENUE_PER_ENROLLED                                 0.583265
# SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED                    0.961660
# CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED                      0.452186
# INSTRUCTION_EXPENDITURE_PER_ENROLLED                         0.975375
# AVG_MATH_4_SCORE                                             0.624610
#
#                                            STATE_REVENUE_PER_ENROLLED  \
# TOTAL_REVENUE_PER_ENROLLED                                   0.705124
# STATE_REVENUE_PER_ENROLLED                                   1.000000
# LOCAL_REVENUE_PER_ENROLLED                                   0.154444
# FEDERAL_REVENUE_PER_ENROLLED                                 0.408105
# SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED                    0.679428
# CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED                      0.310606
# INSTRUCTION_EXPENDITURE_PER_ENROLLED                         0.688307
# AVG_MATH_4_SCORE                                             0.529809
#
#                                            LOCAL_REVENUE_PER_ENROLLED  \
# TOTAL_REVENUE_PER_ENROLLED                                   0.728422
# STATE_REVENUE_PER_ENROLLED                                   0.154444
# LOCAL_REVENUE_PER_ENROLLED                                   1.000000
# FEDERAL_REVENUE_PER_ENROLLED                                 0.276227
# SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED                    0.695987
# CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED                      0.348727
# INSTRUCTION_EXPENDITURE_PER_ENROLLED                         0.729494
# AVG_MATH_4_SCORE                                             0.510576
#
#                                            FEDERAL_REVENUE_PER_ENROLLED  \
# TOTAL_REVENUE_PER_ENROLLED                                     0.583265
# STATE_REVENUE_PER_ENROLLED                                     0.408105
# LOCAL_REVENUE_PER_ENROLLED                                     0.276227
# FEDERAL_REVENUE_PER_ENROLLED                                   1.000000
# SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED                      0.618490
# CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED                        0.343823
# INSTRUCTION_EXPENDITURE_PER_ENROLLED                           0.544670
# AVG_MATH_4_SCORE                                               0.299445
#
#                                            SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED  \
# TOTAL_REVENUE_PER_ENROLLED                                                  0.961660
# STATE_REVENUE_PER_ENROLLED                                                  0.679428
# LOCAL_REVENUE_PER_ENROLLED                                                  0.695987
# FEDERAL_REVENUE_PER_ENROLLED                                                0.618490
# SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED                                   1.000000
# CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED                                     0.421938
# INSTRUCTION_EXPENDITURE_PER_ENROLLED                                        0.929626
# AVG_MATH_4_SCORE                                                            0.562370
#
#                                            CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED  \
# TOTAL_REVENUE_PER_ENROLLED                                                0.452186
# STATE_REVENUE_PER_ENROLLED                                                0.310606
# LOCAL_REVENUE_PER_ENROLLED                                                0.348727
# FEDERAL_REVENUE_PER_ENROLLED                                              0.343823
# SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED                                 0.421938
# CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED                                   1.000000
# INSTRUCTION_EXPENDITURE_PER_ENROLLED                                      0.389196
# AVG_MATH_4_SCORE                                                          0.286703
#
#                                            INSTRUCTION_EXPENDITURE_PER_ENROLLED  \
# TOTAL_REVENUE_PER_ENROLLED                                             0.975375
# STATE_REVENUE_PER_ENROLLED                                             0.688307
# LOCAL_REVENUE_PER_ENROLLED                                             0.729494
# FEDERAL_REVENUE_PER_ENROLLED                                           0.544670
# SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED                              0.929626
# CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED                                0.389196
# INSTRUCTION_EXPENDITURE_PER_ENROLLED                                   1.000000
# AVG_MATH_4_SCORE                                                       0.636188
#
#                                            AVG_MATH_4_SCORE
# TOTAL_REVENUE_PER_ENROLLED                         0.624610
# STATE_REVENUE_PER_ENROLLED                         0.529809
# LOCAL_REVENUE_PER_ENROLLED                         0.510576
# FEDERAL_REVENUE_PER_ENROLLED                       0.299445
# SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED          0.562370
# CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED            0.286703
# INSTRUCTION_EXPENDITURE_PER_ENROLLED               0.636188
# AVG_MATH_4_SCORE                                   1.000000

# %% [markdown]
# Now, we see the spearman correlations involving AVG_MATH_4_SCORE all go up. INSTRUCTION_EXPENDITURE_PER_ENROLLED has the highest coefficient with AVG_MATH_4_SCORE, but it is still relative low.

# %% [markdown]
# Because TOTAL_REVENUE_PER_ENROLLED, SUPPORT_SERVICES_EXPENDITURE_PER_ENROLLED, and INSTRUCTION_EXPENDITURE_PER_ENROLLED have high correlation constants, we can assume that we do not necessarily need all of them as features since adding more will provide not add much information. From that set, we will select INSTRUCTION_EXPENDITURE_PER_ENROLLED.

# %% [markdown]
# That leaves with INSTRUCTION_EXPENDITURE_PER_ENROLLED, CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED, LOCAL_REVENUE_PER_ENROLLED, STATE_REVENUE_PER_ENROLLED, and FEDERAL_REVENUE_PER_ENROLLED, which are still a lot of features.

# %%
# List of potential features
potential_features = [
    'INSTRUCTION_EXPENDITURE_PER_ENROLLED',
    'CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED',
    'LOCAL_REVENUE_PER_ENROLLED',
    'STATE_REVENUE_PER_ENROLLED',
    'FEDERAL_REVENUE_PER_ENROLLED'
]

# %% [markdown]
# Now after looking at the correlation, let us look at the pair plots again for the potential features

# %%
sns.pairplot(df, x_vars=potential_features, y_vars=METRIC_COLUMN, height=6, aspect=.8, kind='reg')

# %% [markdown]
# There ar some outliers on some, such as CAPITAL_OUTLAY_EXPENDITURE, so it might help to remove some outliers from the 98 percentile.

# %% [markdown]
# Looking at the plots, it might make sense to use a nonlinear regression, such a Support Vector Regression with a nonlinear kernel.

# %% [markdown]
# <h2> Data Creation </h2>
#
# Since we will be using the training data to perform feature selection, we will perform the split here

# %%
from sklearn.model_selection import train_test_split

# Let us split up the data into training and testin data using the 80/20 ratio
train, test = train_test_split(df, test_size=0.20, random_state=0)

# %%
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor

# We will be use the Random Forest Regression model because they are optimal for nonlinear data
regression_model = RandomForestRegressor()

# We will RFECV to do the remaining feature selection
model = RFECV(regression_model, step=1, cv=10)

# %%
X_train = train[potential_features]
y_train = train[METRIC_COLUMN]

# Trains the model via 10-Fold Validation, determining which features to remove
model.fit(X_train, y_train)
# Out:
# RFECV(cv=10,
#       estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                       criterion='mse', max_depth=None,
#                                       max_features='auto', max_leaf_nodes=None,
#                                       max_samples=None,
#                                       min_impurity_decrease=0.0,
#                                       min_impurity_split=None,
#                                       min_samples_leaf=1, min_samples_split=2,
#                                       min_weight_fraction_leaf=0.0,
#                                       n_estimators=100, n_jobs=None,
#                                       oob_score=False, random_state=None,
#                                       verbose=0, warm_start=False),
#       min_features_to_select=1, n_jobs=None, scoring=None, step=1, verbose=0)

# %%
# Returns a list of boolean values corresponding to RFECV's decision to include the feature or not
# PLEASE NOTE THAT YOU MIGHT GET OUT A DIFFERENT LIST BECAUSE RFECV USES A RANDOM SEED
model.support_
# Out:
# array([ True, False,  True,  True,  True])

# %%
# Uses model.support_ to filter out the potential features to get the final features
final_features = [feature for (feature, support) in zip(potential_features, model.support_) if support]

# %%
final_features
# Out:
# ['INSTRUCTION_EXPENDITURE_PER_ENROLLED',
#  'LOCAL_REVENUE_PER_ENROLLED',
#  'STATE_REVENUE_PER_ENROLLED',
#  'FEDERAL_REVENUE_PER_ENROLLED']

# %%
# Sees how fell it performs on the TRAINING data after removing the features
model.score(X_train, y_train)
# Out:
# 0.9437840448678687

# %% [markdown]
# Final feature list: Instruction Expenditure per Enrolled, Local Revenue per Enrolled, State Revenue per Enrolled, and Federal Revenue per Enrolled

# %% [markdown]
# Feature selection justification: I picked the features that I did because I first eliminated features that added no additional information (i.e. features that were highly correlated with each other) and the feature (CAPITAL_OUTLAY_EXPENDITURE_PER_ENROLLED) that the RFECV recommended to remove in order to optimize the R2 score.

# %% [markdown]
# <h2> EDA </h2>

# %% [markdown]
# Visualization 1

# %%
format_label = lambda x: ' '.join([seg.capitalize() for seg in x.split('_')])

# %%
# Rename series for better formatting
y_series = df[METRIC_COLUMN]
y_series.name = 'Average 4th Grade Math Scores'

# colors for each graph
color = '#85C1E9' 

# Iterates through each of the final feature to a generate plot
for feature in final_features:
    # formats the label
    x_series = df[feature]
    x_series.name = format_label(feature)
    
    # Remove title because seaborn makes it wonky
    # plt.title('{} vs {}'.format(x_series.name, y_series.name))
    sns.jointplot(x=x_series, y=y_series, kind="reg", color=color)

# %% [markdown]
# Scatter Plots of Each Feature Compared Against The Average Math Score for Fourth Graders (with Distributions included)

# %% [markdown]
# Visualization 2

# %%
ax = sns.kdeplot(df[METRIC_COLUMN])
ax.set_title('KDE Distribution for the Average Grade 4 Math Score')
ax.set_xlabel(format_label(METRIC_COLUMN))
# Out:
# Text(0.5, 0, 'Avg Math 4 Score')

# %% [markdown]
# Kernel Density Estimation of the distribution of the Average Math Scores For 4th Graders

# %% [markdown]
# Please note that this graph is included on the other visualizations

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# Chosen ML task: Regression (Random Forest)

# %%
# Gets the X and y for the testing data
X_test = test[potential_features]
y_test = test[METRIC_COLUMN]

# %%
# We can now score the model, which calculates the R2 score
model.score(X_test, y_test)
# Out:
# 0.6932834918503257

# %%
from sklearn.metrics import r2_score

# Gets the y from prediction the X testing data
y_pred = model.predict(X_test)

# Get the R2 score directly
r2 = r2_score(y_test, y_pred)

# Should be the same as model.score
r2
# Out:
# 0.6932834918503257

# %% [markdown]
# Although we found the R2 score, it typically increases when the number of training point increase too. As a consequence, we should the Adjusted R2 score as well.

# %%
# Gets the number of training data points
n = y_train.shape[0]

# Calculated the Adjusted R2 score
adjusted_r2 = (1 - (1 - r2) * ((n - 1) /  (n - len(final_features) - 1)))
adjusted_r2
# Out:
# 0.6897478548687732

# %% [markdown]
# The adjusted R2 score and the R2 are not too different.

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# The most important features were Instruction Expenditure per Enrolled, Local Revenue per Enrolled, State Revenue per Enrolled, and Federal Revenue per Enrolled. Although, their regression coefficients concerning the average math score for 4 graders, they all tell a picture separately. For example, schools that receive more federal funding usually have less local funding, which might impact the quality of education present (e.g. Baltimore School Systems). Future data analysis can focus on studying how the ratio of local to federal and state to federal are correlated with the test scores. The model's R2 Score and Adjusted R2 Score are around .70 depending on how the random seed that RFECV uses. This score means that the model can explain about 70% of the variations in Test Scores. However, one of the major limitations of the R2 constant is that it can't adequately inform us about how good the model is. We could better assess the model via hypothesis testing in the future.
